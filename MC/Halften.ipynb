# %% [markdown]
# # RL Experiment - Monte Carlo Control

# %%
import sys
import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

from lib.envs.halften import HalftenEnv

env = HalftenEnv()

sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 12})

# log_file = open("training_output.txt", "w", encoding="utf-8")
# sys.stdout = log_file

# %% [markdown]
# ## Monte Carlo Control Implementation
#
# 我们使用ε-greedy策略的首次访问Monte Carlo控制方法。

# %% [markdown]
# ## 在线(online) Monte Carlo

# %%
def make_epsilon_greedy_policy(Q, epsilon, nA):
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        best_action = np.argmax(Q[observation])
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

def mc_control_epsilon_greedy(env, num_episodes, discount_factor=0.8, epsilon=0.005, log_interval=1000):
    returns_sum = defaultdict(float)
    returns_count = defaultdict(float)
    
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    policy = make_epsilon_greedy_policy(Q, epsilon, env.action_space.n)

    
    episode_rewards = []
    avg_rewards = []
    episode_Q_changes = []
    
    for i_episode in range(1, num_episodes + 1):
        episode = []
        state, _ = env.reset()
        
        episode_reward = 0
        
        # 采样生成一整条episode
        for t in range(100):  
            # 蕴含策略改进(Q值变化)
            probs = policy(state)
            
            action = np.random.choice(np.arange(len(probs)), p=probs)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            
            episode.append((state, action, reward))
            episode_reward += reward
            
            if done:
                break
            
            state = next_state
        
        episode_rewards.append(episode_reward)
            
        # 收集episode中出现的所有(s,a)对
        sa_in_episode = set([(x[0], x[1]) for x in episode])
        
        total_Q_change = 0



        # 对每个(s,a)计算折扣回报
        for state, action in sa_in_episode:
            sa_pair = (state, action)
            first_occurence_idx = next(
                i for i, x in enumerate(episode)
                if x[0] == state and x[1] == action)
            
            G = sum([x[2] * (discount_factor ** i)
                for i, x in enumerate(episode[first_occurence_idx:])])
            
            old_Q = Q[state][action]

            returns_sum[sa_pair] += G
            returns_count[sa_pair] += 1.0
            
            Q[state][action] = returns_sum[sa_pair] / returns_count[sa_pair]
            total_Q_change += abs(Q[state][action] - old_Q)
        
        episode_Q_changes.append(total_Q_change)
        
        if i_episode % log_interval == 0:
            recent_rewards = episode_rewards[-log_interval:]
            avg_reward = np.mean(recent_rewards)
            avg_rewards.append((i_episode, avg_reward))
            print(f"Episode {i_episode}/{num_episodes}, Average Reward (last {log_interval} episodes): {avg_reward:.4f}")

    return Q, policy, episode_rewards, avg_rewards, episode_Q_changes

# %% [markdown]
# ## 离线(offline) Monte Carlo

# %%
def mc_control_offline(env, num_episodes, discount_factor=0.8, epsilon=0.005, log_interval=1000):
    """
    Off-policy Monte Carlo Control with Weighted Importance Sampling.
    
    行为策略: epsilon-greedy policy
    目标策略: greedy policy
    回报计算: 回溯方法 (backward return)
    重要性采样: 加权重要性采样 (weighted importance sampling)
    """
    nA = env.action_space.n

    Q = defaultdict(lambda: np.zeros(nA))
    C = defaultdict(lambda: np.zeros(nA))

    episode_rewards = []
    avg_rewards = []
    episode_Q_changes = []

    for i_episode in range(1, num_episodes + 1):
        # 行为策略: ε-greedy
        behavior_policy = make_epsilon_greedy_policy(Q, epsilon, nA)

        # 用行为策略采样一条 episode
        episode = []
        state, _ = env.reset()
        episode_reward = 0

        for t in range(100):
            probs = behavior_policy(state)
            action = np.random.choice(np.arange(nA), p=probs)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            episode.append((state, action, reward))
            episode_reward += reward

            if done:
                break

            state = next_state

        episode_rewards.append(episode_reward)

        # 回溯计算回报 + 加权重要性采样
        G = 0.0
        W = 1.0
        total_Q_change = 0.0

        for t in range(len(episode) - 1, -1, -1):
            state, action, reward = episode[t]

            # 回溯累积回报: G_t = R_{t+1} + γ * G_{t+1}
            G = discount_factor * G + reward

            # 加权重要性采样增量更新
            C[state][action] += W
            old_Q = Q[state][action]
            Q[state][action] += (W / C[state][action]) * (G - Q[state][action])
            total_Q_change += abs(Q[state][action] - old_Q)

            # 目标策略为 greedy: π(s) = argmax_a Q(s, a)
            best_action = np.argmax(Q[state])

            # 若行为策略的动作 ≠ 目标策略的动作，停止向前传播
            if action != best_action:
                break

            # 更新重要性采样比率
            # π(a|s) = 1, b(a|s) = 1 - ε + ε/|A|
            W *= 1.0 / (1.0 - epsilon + epsilon / nA)

        episode_Q_changes.append(total_Q_change)

        if i_episode % log_interval == 0:
            recent_rewards = episode_rewards[-log_interval:]
            avg_reward = np.mean(recent_rewards)
            avg_rewards.append((i_episode, avg_reward))
            print(f"Episode {i_episode}/{num_episodes}, Average Reward (last {log_interval} episodes): {avg_reward:.4f}")

    # 返回目标策略 (greedy)
    target_policy = make_epsilon_greedy_policy(Q, 0.0, nA)

    return Q, target_policy, episode_rewards, avg_rewards, episode_Q_changes

# %% [markdown]
# ## 训练模型
#
# 我们训练50,000个episode来学习最优策略。

# %%
num_episodes = 500000
log_interval = 1000

print(f"开始训练，共{num_episodes}个episode...")
Q, policy, episode_rewards, avg_rewards, episode_Q_changes = mc_control_offline(
    env, 
    num_episodes=num_episodes,
    epsilon=0.1,
    log_interval=log_interval
)

print(f"训练完成！访问了{len(Q)}个不同的状态。")
# Out:
# 开始训练，共500000个episode...
# Episode 1000/500000, Average Reward (last 1000 episodes): 0.4820
# Episode 2000/500000, Average Reward (last 1000 episodes): 0.4940
# Episode 3000/500000, Average Reward (last 1000 episodes): 0.7070
# Episode 4000/500000, Average Reward (last 1000 episodes): 0.6150
# Episode 5000/500000, Average Reward (last 1000 episodes): 0.7140
# Episode 6000/500000, Average Reward (last 1000 episodes): 0.6000
# Episode 7000/500000, Average Reward (last 1000 episodes): 0.7690
# Episode 8000/500000, Average Reward (last 1000 episodes): 0.7000
# Episode 9000/500000, Average Reward (last 1000 episodes): 0.6940
# Episode 10000/500000, Average Reward (last 1000 episodes): 0.6870
# Episode 11000/500000, Average Reward (last 1000 episodes): 0.7730
# Episode 12000/500000, Average Reward (last 1000 episodes): 0.6930
# Episode 13000/500000, Average Reward (last 1000 episodes): 0.6820
# Episode 14000/500000, Average Reward (last 1000 episodes): 0.7210
# Episode 15000/500000, Average Reward (last 1000 episodes): 0.6830
# Episode 16000/500000, Average Reward (last 1000 episodes): 0.7300
# Episode 17000/500000, Average Reward (last 1000 episodes): 0.7550
# Episode 18000/500000, Average Reward (last 1000 episodes): 0.7460
# Episode 19000/500000, Average Reward (last 1000 episodes): 0.6880
# Episode 20000/500000, Average Reward (last 1000 episodes): 0.6120
# Episode 21000/500000, Average Reward (last 1000 episodes): 0.6300
# Episode 22000/500000, Average Reward (last 1000 episodes): 0.5990
# Episode 23000/500000, Average Reward (last 1000 episodes): 0.7610
# Episode 24000/500000, Average Reward (last 1000 episodes): 0.6540
# Episode 25000/500000, Average Reward (last 1000 episodes): 0.6180
# Episode 26000/500000, Average Reward (last 1000 episodes): 0.6020
# Episode 27000/500000, Average Reward (last 1000 episodes): 0.6050
# Episode 28000/500000, Average Reward (last 1000 episodes): 0.5490
# Episode 29000/500000, Average Reward (last 1000 episodes): 0.6760
# Episode 30000/500000, Average Reward (last 1000 episodes): 0.6930
# Episode 31000/500000, Average Reward (last 1000 episodes): 0.6110
# Episode 32000/500000, Average Reward (last 1000 episodes): 0.6620
# Episode 33000/500000, Average Reward (last 1000 episodes): 0.6420
# Episode 34000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 35000/500000, Average Reward (last 1000 episodes): 0.7360
# Episode 36000/500000, Average Reward (last 1000 episodes): 0.6500
# Episode 37000/500000, Average Reward (last 1000 episodes): 0.6400
# Episode 38000/500000, Average Reward (last 1000 episodes): 0.7580
# Episode 39000/500000, Average Reward (last 1000 episodes): 0.5430
# Episode 40000/500000, Average Reward (last 1000 episodes): 0.7490
# Episode 41000/500000, Average Reward (last 1000 episodes): 0.7580
# Episode 42000/500000, Average Reward (last 1000 episodes): 0.5930
# Episode 43000/500000, Average Reward (last 1000 episodes): 0.6610
# Episode 44000/500000, Average Reward (last 1000 episodes): 0.8290
# Episode 45000/500000, Average Reward (last 1000 episodes): 0.7190
# Episode 46000/500000, Average Reward (last 1000 episodes): 0.7130
# Episode 47000/500000, Average Reward (last 1000 episodes): 0.7100
# Episode 48000/500000, Average Reward (last 1000 episodes): 0.7090
# Episode 49000/500000, Average Reward (last 1000 episodes): 0.7400
# Episode 50000/500000, Average Reward (last 1000 episodes): 0.6700
# Episode 51000/500000, Average Reward (last 1000 episodes): 0.6920
# Episode 52000/500000, Average Reward (last 1000 episodes): 0.6840
# Episode 53000/500000, Average Reward (last 1000 episodes): 0.6860
# Episode 54000/500000, Average Reward (last 1000 episodes): 0.7100
# Episode 55000/500000, Average Reward (last 1000 episodes): 0.7590
# Episode 56000/500000, Average Reward (last 1000 episodes): 0.7250
# Episode 57000/500000, Average Reward (last 1000 episodes): 0.6840
# Episode 58000/500000, Average Reward (last 1000 episodes): 0.7210
# Episode 59000/500000, Average Reward (last 1000 episodes): 0.6860
# Episode 60000/500000, Average Reward (last 1000 episodes): 0.6510
# Episode 61000/500000, Average Reward (last 1000 episodes): 0.6940
# Episode 62000/500000, Average Reward (last 1000 episodes): 0.7610
# Episode 63000/500000, Average Reward (last 1000 episodes): 0.6300
# Episode 64000/500000, Average Reward (last 1000 episodes): 0.6030
# Episode 65000/500000, Average Reward (last 1000 episodes): 0.5560
# Episode 66000/500000, Average Reward (last 1000 episodes): 0.7340
# Episode 67000/500000, Average Reward (last 1000 episodes): 0.8050
# Episode 68000/500000, Average Reward (last 1000 episodes): 0.7530
# Episode 69000/500000, Average Reward (last 1000 episodes): 0.7290
# Episode 70000/500000, Average Reward (last 1000 episodes): 0.6300
# Episode 71000/500000, Average Reward (last 1000 episodes): 0.7630
# Episode 72000/500000, Average Reward (last 1000 episodes): 0.6440
# Episode 73000/500000, Average Reward (last 1000 episodes): 0.6740
# Episode 74000/500000, Average Reward (last 1000 episodes): 0.6460
# Episode 75000/500000, Average Reward (last 1000 episodes): 0.6370
# Episode 76000/500000, Average Reward (last 1000 episodes): 0.6750
# Episode 77000/500000, Average Reward (last 1000 episodes): 0.6540
# Episode 78000/500000, Average Reward (last 1000 episodes): 0.6350
# Episode 79000/500000, Average Reward (last 1000 episodes): 0.5840
# Episode 80000/500000, Average Reward (last 1000 episodes): 0.7720
# Episode 81000/500000, Average Reward (last 1000 episodes): 0.7110
# Episode 82000/500000, Average Reward (last 1000 episodes): 0.7450
# Episode 83000/500000, Average Reward (last 1000 episodes): 0.6600
# Episode 84000/500000, Average Reward (last 1000 episodes): 0.6600
# Episode 85000/500000, Average Reward (last 1000 episodes): 0.6720
# Episode 86000/500000, Average Reward (last 1000 episodes): 0.6680
# Episode 87000/500000, Average Reward (last 1000 episodes): 0.7570
# Episode 88000/500000, Average Reward (last 1000 episodes): 0.7690
# Episode 89000/500000, Average Reward (last 1000 episodes): 0.6160
# Episode 90000/500000, Average Reward (last 1000 episodes): 0.6360
# Episode 91000/500000, Average Reward (last 1000 episodes): 0.7080
# Episode 92000/500000, Average Reward (last 1000 episodes): 0.6710
# Episode 93000/500000, Average Reward (last 1000 episodes): 0.6920
# Episode 94000/500000, Average Reward (last 1000 episodes): 0.7160
# Episode 95000/500000, Average Reward (last 1000 episodes): 0.6670
# Episode 96000/500000, Average Reward (last 1000 episodes): 0.7390
# Episode 97000/500000, Average Reward (last 1000 episodes): 0.7610
# Episode 98000/500000, Average Reward (last 1000 episodes): 0.7660
# Episode 99000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 100000/500000, Average Reward (last 1000 episodes): 0.6830
# Episode 101000/500000, Average Reward (last 1000 episodes): 0.5670
# Episode 102000/500000, Average Reward (last 1000 episodes): 0.5860
# Episode 103000/500000, Average Reward (last 1000 episodes): 0.6260
# Episode 104000/500000, Average Reward (last 1000 episodes): 0.6990
# Episode 105000/500000, Average Reward (last 1000 episodes): 0.5820
# Episode 106000/500000, Average Reward (last 1000 episodes): 0.7740
# Episode 107000/500000, Average Reward (last 1000 episodes): 0.6720
# Episode 108000/500000, Average Reward (last 1000 episodes): 0.6940
# Episode 109000/500000, Average Reward (last 1000 episodes): 0.6950
# Episode 110000/500000, Average Reward (last 1000 episodes): 0.7220
# Episode 111000/500000, Average Reward (last 1000 episodes): 0.7310
# Episode 112000/500000, Average Reward (last 1000 episodes): 0.7630
# Episode 113000/500000, Average Reward (last 1000 episodes): 0.5510
# Episode 114000/500000, Average Reward (last 1000 episodes): 0.6680
# Episode 115000/500000, Average Reward (last 1000 episodes): 0.6790
# Episode 116000/500000, Average Reward (last 1000 episodes): 0.5330
# Episode 117000/500000, Average Reward (last 1000 episodes): 0.6020
# Episode 118000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 119000/500000, Average Reward (last 1000 episodes): 0.7600
# Episode 120000/500000, Average Reward (last 1000 episodes): 0.6230
# Episode 121000/500000, Average Reward (last 1000 episodes): 0.6240
# Episode 122000/500000, Average Reward (last 1000 episodes): 0.6490
# Episode 123000/500000, Average Reward (last 1000 episodes): 0.7790
# Episode 124000/500000, Average Reward (last 1000 episodes): 0.6490
# Episode 125000/500000, Average Reward (last 1000 episodes): 0.6590
# Episode 126000/500000, Average Reward (last 1000 episodes): 0.5470
# Episode 127000/500000, Average Reward (last 1000 episodes): 0.6920
# Episode 128000/500000, Average Reward (last 1000 episodes): 0.6290
# Episode 129000/500000, Average Reward (last 1000 episodes): 0.6320
# Episode 130000/500000, Average Reward (last 1000 episodes): 0.5940
# Episode 131000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 132000/500000, Average Reward (last 1000 episodes): 0.6700
# Episode 133000/500000, Average Reward (last 1000 episodes): 0.6340
# Episode 134000/500000, Average Reward (last 1000 episodes): 0.6740
# Episode 135000/500000, Average Reward (last 1000 episodes): 0.6470
# Episode 136000/500000, Average Reward (last 1000 episodes): 0.5990
# Episode 137000/500000, Average Reward (last 1000 episodes): 0.6910
# Episode 138000/500000, Average Reward (last 1000 episodes): 0.6970
# Episode 139000/500000, Average Reward (last 1000 episodes): 0.8150
# Episode 140000/500000, Average Reward (last 1000 episodes): 0.7920
# Episode 141000/500000, Average Reward (last 1000 episodes): 0.7680
# Episode 142000/500000, Average Reward (last 1000 episodes): 0.5770
# Episode 143000/500000, Average Reward (last 1000 episodes): 0.6580
# Episode 144000/500000, Average Reward (last 1000 episodes): 0.6350
# Episode 145000/500000, Average Reward (last 1000 episodes): 0.7030
# Episode 146000/500000, Average Reward (last 1000 episodes): 0.6760
# Episode 147000/500000, Average Reward (last 1000 episodes): 0.6810
# Episode 148000/500000, Average Reward (last 1000 episodes): 0.8500
# Episode 149000/500000, Average Reward (last 1000 episodes): 0.7060
# Episode 150000/500000, Average Reward (last 1000 episodes): 0.5900
# Episode 151000/500000, Average Reward (last 1000 episodes): 0.6720
# Episode 152000/500000, Average Reward (last 1000 episodes): 0.7620
# Episode 153000/500000, Average Reward (last 1000 episodes): 0.7470
# Episode 154000/500000, Average Reward (last 1000 episodes): 0.6550
# Episode 155000/500000, Average Reward (last 1000 episodes): 0.5880
# Episode 156000/500000, Average Reward (last 1000 episodes): 0.6840
# Episode 157000/500000, Average Reward (last 1000 episodes): 0.6470
# Episode 158000/500000, Average Reward (last 1000 episodes): 0.7480
# Episode 159000/500000, Average Reward (last 1000 episodes): 0.7000
# Episode 160000/500000, Average Reward (last 1000 episodes): 0.7180
# Episode 161000/500000, Average Reward (last 1000 episodes): 0.6750
# Episode 162000/500000, Average Reward (last 1000 episodes): 0.6390
# Episode 163000/500000, Average Reward (last 1000 episodes): 0.6760
# Episode 164000/500000, Average Reward (last 1000 episodes): 0.6580
# Episode 165000/500000, Average Reward (last 1000 episodes): 0.6310
# Episode 166000/500000, Average Reward (last 1000 episodes): 0.6020
# Episode 167000/500000, Average Reward (last 1000 episodes): 0.5790
# Episode 168000/500000, Average Reward (last 1000 episodes): 0.6300
# Episode 169000/500000, Average Reward (last 1000 episodes): 0.6430
# Episode 170000/500000, Average Reward (last 1000 episodes): 0.6770
# Episode 171000/500000, Average Reward (last 1000 episodes): 0.7760
# Episode 172000/500000, Average Reward (last 1000 episodes): 0.7160
# Episode 173000/500000, Average Reward (last 1000 episodes): 0.6760
# Episode 174000/500000, Average Reward (last 1000 episodes): 0.6550
# Episode 175000/500000, Average Reward (last 1000 episodes): 0.6620
# Episode 176000/500000, Average Reward (last 1000 episodes): 0.6260
# Episode 177000/500000, Average Reward (last 1000 episodes): 0.6130
# Episode 178000/500000, Average Reward (last 1000 episodes): 0.6700
# Episode 179000/500000, Average Reward (last 1000 episodes): 0.7750
# Episode 180000/500000, Average Reward (last 1000 episodes): 0.6280
# Episode 181000/500000, Average Reward (last 1000 episodes): 0.6700
# Episode 182000/500000, Average Reward (last 1000 episodes): 0.6950
# Episode 183000/500000, Average Reward (last 1000 episodes): 0.7690
# Episode 184000/500000, Average Reward (last 1000 episodes): 0.7440
# Episode 185000/500000, Average Reward (last 1000 episodes): 0.6910
# Episode 186000/500000, Average Reward (last 1000 episodes): 0.6470
# Episode 187000/500000, Average Reward (last 1000 episodes): 0.6350
# Episode 188000/500000, Average Reward (last 1000 episodes): 0.7040
# Episode 189000/500000, Average Reward (last 1000 episodes): 0.6900
# Episode 190000/500000, Average Reward (last 1000 episodes): 0.7430
# Episode 191000/500000, Average Reward (last 1000 episodes): 0.6010
# Episode 192000/500000, Average Reward (last 1000 episodes): 0.7130
# Episode 193000/500000, Average Reward (last 1000 episodes): 0.6960
# Episode 194000/500000, Average Reward (last 1000 episodes): 0.5270
# Episode 195000/500000, Average Reward (last 1000 episodes): 0.6690
# Episode 196000/500000, Average Reward (last 1000 episodes): 0.6380
# Episode 197000/500000, Average Reward (last 1000 episodes): 0.7100
# Episode 198000/500000, Average Reward (last 1000 episodes): 0.7050
# Episode 199000/500000, Average Reward (last 1000 episodes): 0.7220
# Episode 200000/500000, Average Reward (last 1000 episodes): 0.7040
# Episode 201000/500000, Average Reward (last 1000 episodes): 0.6850
# Episode 202000/500000, Average Reward (last 1000 episodes): 0.7670
# Episode 203000/500000, Average Reward (last 1000 episodes): 0.6310
# Episode 204000/500000, Average Reward (last 1000 episodes): 0.6470
# Episode 205000/500000, Average Reward (last 1000 episodes): 0.6520
# Episode 206000/500000, Average Reward (last 1000 episodes): 0.6410
# Episode 207000/500000, Average Reward (last 1000 episodes): 0.5570
# Episode 208000/500000, Average Reward (last 1000 episodes): 0.7310
# Episode 209000/500000, Average Reward (last 1000 episodes): 0.6430
# Episode 210000/500000, Average Reward (last 1000 episodes): 0.5980
# Episode 211000/500000, Average Reward (last 1000 episodes): 0.7410
# Episode 212000/500000, Average Reward (last 1000 episodes): 0.7090
# Episode 213000/500000, Average Reward (last 1000 episodes): 0.7770
# Episode 214000/500000, Average Reward (last 1000 episodes): 0.6110
# Episode 215000/500000, Average Reward (last 1000 episodes): 0.7900
# Episode 216000/500000, Average Reward (last 1000 episodes): 0.6000
# Episode 217000/500000, Average Reward (last 1000 episodes): 0.6970
# Episode 218000/500000, Average Reward (last 1000 episodes): 0.6370
# Episode 219000/500000, Average Reward (last 1000 episodes): 0.7900
# Episode 220000/500000, Average Reward (last 1000 episodes): 0.7380
# Episode 221000/500000, Average Reward (last 1000 episodes): 0.6570
# Episode 222000/500000, Average Reward (last 1000 episodes): 0.5900
# Episode 223000/500000, Average Reward (last 1000 episodes): 0.7130
# Episode 224000/500000, Average Reward (last 1000 episodes): 0.6530
# Episode 225000/500000, Average Reward (last 1000 episodes): 0.7060
# Episode 226000/500000, Average Reward (last 1000 episodes): 0.7400
# Episode 227000/500000, Average Reward (last 1000 episodes): 0.6770
# Episode 228000/500000, Average Reward (last 1000 episodes): 0.8260
# Episode 229000/500000, Average Reward (last 1000 episodes): 0.6520
# Episode 230000/500000, Average Reward (last 1000 episodes): 0.5760
# Episode 231000/500000, Average Reward (last 1000 episodes): 0.6010
# Episode 232000/500000, Average Reward (last 1000 episodes): 0.7400
# Episode 233000/500000, Average Reward (last 1000 episodes): 0.6300
# Episode 234000/500000, Average Reward (last 1000 episodes): 0.7210
# Episode 235000/500000, Average Reward (last 1000 episodes): 0.6710
# Episode 236000/500000, Average Reward (last 1000 episodes): 0.5900
# Episode 237000/500000, Average Reward (last 1000 episodes): 0.5780
# Episode 238000/500000, Average Reward (last 1000 episodes): 0.6600
# Episode 239000/500000, Average Reward (last 1000 episodes): 0.7500
# Episode 240000/500000, Average Reward (last 1000 episodes): 0.7080
# Episode 241000/500000, Average Reward (last 1000 episodes): 0.6210
# Episode 242000/500000, Average Reward (last 1000 episodes): 0.6020
# Episode 243000/500000, Average Reward (last 1000 episodes): 0.6170
# Episode 244000/500000, Average Reward (last 1000 episodes): 0.6950
# Episode 245000/500000, Average Reward (last 1000 episodes): 0.5970
# Episode 246000/500000, Average Reward (last 1000 episodes): 0.6730
# Episode 247000/500000, Average Reward (last 1000 episodes): 0.6200
# Episode 248000/500000, Average Reward (last 1000 episodes): 0.7930
# Episode 249000/500000, Average Reward (last 1000 episodes): 0.5800
# Episode 250000/500000, Average Reward (last 1000 episodes): 0.6930
# Episode 251000/500000, Average Reward (last 1000 episodes): 0.6930
# Episode 252000/500000, Average Reward (last 1000 episodes): 0.7090
# Episode 253000/500000, Average Reward (last 1000 episodes): 0.7470
# Episode 254000/500000, Average Reward (last 1000 episodes): 0.7160
# Episode 255000/500000, Average Reward (last 1000 episodes): 0.6240
# Episode 256000/500000, Average Reward (last 1000 episodes): 0.6890
# Episode 257000/500000, Average Reward (last 1000 episodes): 0.8020
# Episode 258000/500000, Average Reward (last 1000 episodes): 0.6870
# Episode 259000/500000, Average Reward (last 1000 episodes): 0.7840
# Episode 260000/500000, Average Reward (last 1000 episodes): 0.6410
# Episode 261000/500000, Average Reward (last 1000 episodes): 0.6950
# Episode 262000/500000, Average Reward (last 1000 episodes): 0.7260
# Episode 263000/500000, Average Reward (last 1000 episodes): 0.6490
# Episode 264000/500000, Average Reward (last 1000 episodes): 0.6630
# Episode 265000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 266000/500000, Average Reward (last 1000 episodes): 0.6880
# Episode 267000/500000, Average Reward (last 1000 episodes): 0.6710
# Episode 268000/500000, Average Reward (last 1000 episodes): 0.6250
# Episode 269000/500000, Average Reward (last 1000 episodes): 0.7600
# Episode 270000/500000, Average Reward (last 1000 episodes): 0.7960
# Episode 271000/500000, Average Reward (last 1000 episodes): 0.7700
# Episode 272000/500000, Average Reward (last 1000 episodes): 0.5640
# Episode 273000/500000, Average Reward (last 1000 episodes): 0.6290
# Episode 274000/500000, Average Reward (last 1000 episodes): 0.6990
# Episode 275000/500000, Average Reward (last 1000 episodes): 0.6750
# Episode 276000/500000, Average Reward (last 1000 episodes): 0.5760
# Episode 277000/500000, Average Reward (last 1000 episodes): 0.6760
# Episode 278000/500000, Average Reward (last 1000 episodes): 0.6750
# Episode 279000/500000, Average Reward (last 1000 episodes): 0.8020
# Episode 280000/500000, Average Reward (last 1000 episodes): 0.7030
# Episode 281000/500000, Average Reward (last 1000 episodes): 0.6430
# Episode 282000/500000, Average Reward (last 1000 episodes): 0.7200
# Episode 283000/500000, Average Reward (last 1000 episodes): 0.7330
# Episode 284000/500000, Average Reward (last 1000 episodes): 0.5510
# Episode 285000/500000, Average Reward (last 1000 episodes): 0.5930
# Episode 286000/500000, Average Reward (last 1000 episodes): 0.6550
# Episode 287000/500000, Average Reward (last 1000 episodes): 0.6650
# Episode 288000/500000, Average Reward (last 1000 episodes): 0.6360
# Episode 289000/500000, Average Reward (last 1000 episodes): 0.5890
# Episode 290000/500000, Average Reward (last 1000 episodes): 0.7160
# Episode 291000/500000, Average Reward (last 1000 episodes): 0.7250
# Episode 292000/500000, Average Reward (last 1000 episodes): 0.7080
# Episode 293000/500000, Average Reward (last 1000 episodes): 0.7280
# Episode 294000/500000, Average Reward (last 1000 episodes): 0.6180
# Episode 295000/500000, Average Reward (last 1000 episodes): 0.6660
# Episode 296000/500000, Average Reward (last 1000 episodes): 0.6700
# Episode 297000/500000, Average Reward (last 1000 episodes): 0.6600
# Episode 298000/500000, Average Reward (last 1000 episodes): 0.6890
# Episode 299000/500000, Average Reward (last 1000 episodes): 0.7490
# Episode 300000/500000, Average Reward (last 1000 episodes): 0.6720
# Episode 301000/500000, Average Reward (last 1000 episodes): 0.5910
# Episode 302000/500000, Average Reward (last 1000 episodes): 0.7340
# Episode 303000/500000, Average Reward (last 1000 episodes): 0.6720
# Episode 304000/500000, Average Reward (last 1000 episodes): 0.7960
# Episode 305000/500000, Average Reward (last 1000 episodes): 0.6660
# Episode 306000/500000, Average Reward (last 1000 episodes): 0.7110
# Episode 307000/500000, Average Reward (last 1000 episodes): 0.6640
# Episode 308000/500000, Average Reward (last 1000 episodes): 0.6950
# Episode 309000/500000, Average Reward (last 1000 episodes): 0.5360
# Episode 310000/500000, Average Reward (last 1000 episodes): 0.7710
# Episode 311000/500000, Average Reward (last 1000 episodes): 0.6050
# Episode 312000/500000, Average Reward (last 1000 episodes): 0.6550
# Episode 313000/500000, Average Reward (last 1000 episodes): 0.7370
# Episode 314000/500000, Average Reward (last 1000 episodes): 0.7630
# Episode 315000/500000, Average Reward (last 1000 episodes): 0.6160
# Episode 316000/500000, Average Reward (last 1000 episodes): 0.6860
# Episode 317000/500000, Average Reward (last 1000 episodes): 0.7540
# Episode 318000/500000, Average Reward (last 1000 episodes): 0.6480
# Episode 319000/500000, Average Reward (last 1000 episodes): 0.8140
# Episode 320000/500000, Average Reward (last 1000 episodes): 0.6610
# Episode 321000/500000, Average Reward (last 1000 episodes): 0.6010
# Episode 322000/500000, Average Reward (last 1000 episodes): 0.7540
# Episode 323000/500000, Average Reward (last 1000 episodes): 0.7310
# Episode 324000/500000, Average Reward (last 1000 episodes): 0.7090
# Episode 325000/500000, Average Reward (last 1000 episodes): 0.6590
# Episode 326000/500000, Average Reward (last 1000 episodes): 0.6880
# Episode 327000/500000, Average Reward (last 1000 episodes): 0.6770
# Episode 328000/500000, Average Reward (last 1000 episodes): 0.7470
# Episode 329000/500000, Average Reward (last 1000 episodes): 0.6620
# Episode 330000/500000, Average Reward (last 1000 episodes): 0.7160
# Episode 331000/500000, Average Reward (last 1000 episodes): 0.7100
# Episode 332000/500000, Average Reward (last 1000 episodes): 0.6850
# Episode 333000/500000, Average Reward (last 1000 episodes): 0.6470
# Episode 334000/500000, Average Reward (last 1000 episodes): 0.7360
# Episode 335000/500000, Average Reward (last 1000 episodes): 0.6540
# Episode 336000/500000, Average Reward (last 1000 episodes): 0.6520
# Episode 337000/500000, Average Reward (last 1000 episodes): 0.6140
# Episode 338000/500000, Average Reward (last 1000 episodes): 0.8010
# Episode 339000/500000, Average Reward (last 1000 episodes): 0.6590
# Episode 340000/500000, Average Reward (last 1000 episodes): 0.5960
# Episode 341000/500000, Average Reward (last 1000 episodes): 0.7640
# Episode 342000/500000, Average Reward (last 1000 episodes): 0.7520
# Episode 343000/500000, Average Reward (last 1000 episodes): 0.6780
# Episode 344000/500000, Average Reward (last 1000 episodes): 0.7240
# Episode 345000/500000, Average Reward (last 1000 episodes): 0.6470
# Episode 346000/500000, Average Reward (last 1000 episodes): 0.6850
# Episode 347000/500000, Average Reward (last 1000 episodes): 0.6110
# Episode 348000/500000, Average Reward (last 1000 episodes): 0.7150
# Episode 349000/500000, Average Reward (last 1000 episodes): 0.6820
# Episode 350000/500000, Average Reward (last 1000 episodes): 0.6270
# Episode 351000/500000, Average Reward (last 1000 episodes): 0.7400
# Episode 352000/500000, Average Reward (last 1000 episodes): 0.7110
# Episode 353000/500000, Average Reward (last 1000 episodes): 0.7200
# Episode 354000/500000, Average Reward (last 1000 episodes): 0.7050
# Episode 355000/500000, Average Reward (last 1000 episodes): 0.6490
# Episode 356000/500000, Average Reward (last 1000 episodes): 0.6730
# Episode 357000/500000, Average Reward (last 1000 episodes): 0.6740
# Episode 358000/500000, Average Reward (last 1000 episodes): 0.8060
# Episode 359000/500000, Average Reward (last 1000 episodes): 0.6640
# Episode 360000/500000, Average Reward (last 1000 episodes): 0.7040
# Episode 361000/500000, Average Reward (last 1000 episodes): 0.7580
# Episode 362000/500000, Average Reward (last 1000 episodes): 0.6410
# Episode 363000/500000, Average Reward (last 1000 episodes): 0.6430
# Episode 364000/500000, Average Reward (last 1000 episodes): 0.5610
# Episode 365000/500000, Average Reward (last 1000 episodes): 0.7320
# Episode 366000/500000, Average Reward (last 1000 episodes): 0.6530
# Episode 367000/500000, Average Reward (last 1000 episodes): 0.6530
# Episode 368000/500000, Average Reward (last 1000 episodes): 0.7220
# Episode 369000/500000, Average Reward (last 1000 episodes): 0.6610
# Episode 370000/500000, Average Reward (last 1000 episodes): 0.7350
# Episode 371000/500000, Average Reward (last 1000 episodes): 0.7630
# Episode 372000/500000, Average Reward (last 1000 episodes): 0.5540
# Episode 373000/500000, Average Reward (last 1000 episodes): 0.7030
# Episode 374000/500000, Average Reward (last 1000 episodes): 0.7060
# Episode 375000/500000, Average Reward (last 1000 episodes): 0.6130
# Episode 376000/500000, Average Reward (last 1000 episodes): 0.5370
# Episode 377000/500000, Average Reward (last 1000 episodes): 0.7230
# Episode 378000/500000, Average Reward (last 1000 episodes): 0.7370
# Episode 379000/500000, Average Reward (last 1000 episodes): 0.7270
# Episode 380000/500000, Average Reward (last 1000 episodes): 0.6340
# Episode 381000/500000, Average Reward (last 1000 episodes): 0.6510
# Episode 382000/500000, Average Reward (last 1000 episodes): 0.7270
# Episode 383000/500000, Average Reward (last 1000 episodes): 0.6930
# Episode 384000/500000, Average Reward (last 1000 episodes): 0.7410
# Episode 385000/500000, Average Reward (last 1000 episodes): 0.6910
# Episode 386000/500000, Average Reward (last 1000 episodes): 0.7500
# Episode 387000/500000, Average Reward (last 1000 episodes): 0.7020
# Episode 388000/500000, Average Reward (last 1000 episodes): 0.6950
# Episode 389000/500000, Average Reward (last 1000 episodes): 0.6110
# Episode 390000/500000, Average Reward (last 1000 episodes): 0.5990
# Episode 391000/500000, Average Reward (last 1000 episodes): 0.6870
# Episode 392000/500000, Average Reward (last 1000 episodes): 0.7000
# Episode 393000/500000, Average Reward (last 1000 episodes): 0.6400
# Episode 394000/500000, Average Reward (last 1000 episodes): 0.6480
# Episode 395000/500000, Average Reward (last 1000 episodes): 0.7440
# Episode 396000/500000, Average Reward (last 1000 episodes): 0.6740
# Episode 397000/500000, Average Reward (last 1000 episodes): 0.6840
# Episode 398000/500000, Average Reward (last 1000 episodes): 0.7360
# Episode 399000/500000, Average Reward (last 1000 episodes): 0.7590
# Episode 400000/500000, Average Reward (last 1000 episodes): 0.7200
# Episode 401000/500000, Average Reward (last 1000 episodes): 0.6160
# Episode 402000/500000, Average Reward (last 1000 episodes): 0.6560
# Episode 403000/500000, Average Reward (last 1000 episodes): 0.6530
# Episode 404000/500000, Average Reward (last 1000 episodes): 0.7340
# Episode 405000/500000, Average Reward (last 1000 episodes): 0.7080
# Episode 406000/500000, Average Reward (last 1000 episodes): 0.6920
# Episode 407000/500000, Average Reward (last 1000 episodes): 0.7000
# Episode 408000/500000, Average Reward (last 1000 episodes): 0.6200
# Episode 409000/500000, Average Reward (last 1000 episodes): 0.6880
# Episode 410000/500000, Average Reward (last 1000 episodes): 0.5990
# Episode 411000/500000, Average Reward (last 1000 episodes): 0.6310
# Episode 412000/500000, Average Reward (last 1000 episodes): 0.7970
# Episode 413000/500000, Average Reward (last 1000 episodes): 0.7500
# Episode 414000/500000, Average Reward (last 1000 episodes): 0.6780
# Episode 415000/500000, Average Reward (last 1000 episodes): 0.6140
# Episode 416000/500000, Average Reward (last 1000 episodes): 0.6020
# Episode 417000/500000, Average Reward (last 1000 episodes): 0.6760
# Episode 418000/500000, Average Reward (last 1000 episodes): 0.6860
# Episode 419000/500000, Average Reward (last 1000 episodes): 0.6300
# Episode 420000/500000, Average Reward (last 1000 episodes): 0.6420
# Episode 421000/500000, Average Reward (last 1000 episodes): 0.6650
# Episode 422000/500000, Average Reward (last 1000 episodes): 0.5830
# Episode 423000/500000, Average Reward (last 1000 episodes): 0.7340
# Episode 424000/500000, Average Reward (last 1000 episodes): 0.6170
# Episode 425000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 426000/500000, Average Reward (last 1000 episodes): 0.6980
# Episode 427000/500000, Average Reward (last 1000 episodes): 0.6220
# Episode 428000/500000, Average Reward (last 1000 episodes): 0.7450
# Episode 429000/500000, Average Reward (last 1000 episodes): 0.7500
# Episode 430000/500000, Average Reward (last 1000 episodes): 0.6940
# Episode 431000/500000, Average Reward (last 1000 episodes): 0.7030
# Episode 432000/500000, Average Reward (last 1000 episodes): 0.6590
# Episode 433000/500000, Average Reward (last 1000 episodes): 0.7360
# Episode 434000/500000, Average Reward (last 1000 episodes): 0.6910
# Episode 435000/500000, Average Reward (last 1000 episodes): 0.6970
# Episode 436000/500000, Average Reward (last 1000 episodes): 0.6710
# Episode 437000/500000, Average Reward (last 1000 episodes): 0.5810
# Episode 438000/500000, Average Reward (last 1000 episodes): 0.6940
# Episode 439000/500000, Average Reward (last 1000 episodes): 0.7590
# Episode 440000/500000, Average Reward (last 1000 episodes): 0.7780
# Episode 441000/500000, Average Reward (last 1000 episodes): 0.5850
# Episode 442000/500000, Average Reward (last 1000 episodes): 0.7110
# Episode 443000/500000, Average Reward (last 1000 episodes): 0.7620
# Episode 444000/500000, Average Reward (last 1000 episodes): 0.7200
# Episode 445000/500000, Average Reward (last 1000 episodes): 0.5860
# Episode 446000/500000, Average Reward (last 1000 episodes): 0.6160
# Episode 447000/500000, Average Reward (last 1000 episodes): 0.6750
# Episode 448000/500000, Average Reward (last 1000 episodes): 0.6370
# Episode 449000/500000, Average Reward (last 1000 episodes): 0.7050
# Episode 450000/500000, Average Reward (last 1000 episodes): 0.6030
# Episode 451000/500000, Average Reward (last 1000 episodes): 0.6990
# Episode 452000/500000, Average Reward (last 1000 episodes): 0.6650
# Episode 453000/500000, Average Reward (last 1000 episodes): 0.7150
# Episode 454000/500000, Average Reward (last 1000 episodes): 0.6330
# Episode 455000/500000, Average Reward (last 1000 episodes): 0.7110
# Episode 456000/500000, Average Reward (last 1000 episodes): 0.5790
# Episode 457000/500000, Average Reward (last 1000 episodes): 0.6240
# Episode 458000/500000, Average Reward (last 1000 episodes): 0.6520
# Episode 459000/500000, Average Reward (last 1000 episodes): 0.6800
# Episode 460000/500000, Average Reward (last 1000 episodes): 0.8200
# Episode 461000/500000, Average Reward (last 1000 episodes): 0.6340
# Episode 462000/500000, Average Reward (last 1000 episodes): 0.6620
# Episode 463000/500000, Average Reward (last 1000 episodes): 0.6270
# Episode 464000/500000, Average Reward (last 1000 episodes): 0.7620
# Episode 465000/500000, Average Reward (last 1000 episodes): 0.6990
# Episode 466000/500000, Average Reward (last 1000 episodes): 0.6700
# Episode 467000/500000, Average Reward (last 1000 episodes): 0.7260
# Episode 468000/500000, Average Reward (last 1000 episodes): 0.7610
# Episode 469000/500000, Average Reward (last 1000 episodes): 0.7070
# Episode 470000/500000, Average Reward (last 1000 episodes): 0.6500
# Episode 471000/500000, Average Reward (last 1000 episodes): 0.6390
# Episode 472000/500000, Average Reward (last 1000 episodes): 0.5900
# Episode 473000/500000, Average Reward (last 1000 episodes): 0.7220
# Episode 474000/500000, Average Reward (last 1000 episodes): 0.6050
# Episode 475000/500000, Average Reward (last 1000 episodes): 0.7490
# Episode 476000/500000, Average Reward (last 1000 episodes): 0.7240
# Episode 477000/500000, Average Reward (last 1000 episodes): 0.6860
# Episode 478000/500000, Average Reward (last 1000 episodes): 0.7420
# Episode 479000/500000, Average Reward (last 1000 episodes): 0.6540
# Episode 480000/500000, Average Reward (last 1000 episodes): 0.6400
# Episode 481000/500000, Average Reward (last 1000 episodes): 0.6680
# Episode 482000/500000, Average Reward (last 1000 episodes): 0.6550
# Episode 483000/500000, Average Reward (last 1000 episodes): 0.6720
# Episode 484000/500000, Average Reward (last 1000 episodes): 0.6020
# Episode 485000/500000, Average Reward (last 1000 episodes): 0.7380
# Episode 486000/500000, Average Reward (last 1000 episodes): 0.6620
# Episode 487000/500000, Average Reward (last 1000 episodes): 0.7560
# Episode 488000/500000, Average Reward (last 1000 episodes): 0.7020
# Episode 489000/500000, Average Reward (last 1000 episodes): 0.7000
# Episode 490000/500000, Average Reward (last 1000 episodes): 0.7090
# Episode 491000/500000, Average Reward (last 1000 episodes): 0.6340
# Episode 492000/500000, Average Reward (last 1000 episodes): 0.7060
# Episode 493000/500000, Average Reward (last 1000 episodes): 0.7310
# Episode 494000/500000, Average Reward (last 1000 episodes): 0.6440
# Episode 495000/500000, Average Reward (last 1000 episodes): 0.6410
# Episode 496000/500000, Average Reward (last 1000 episodes): 0.6680
# Episode 497000/500000, Average Reward (last 1000 episodes): 0.6640
# Episode 498000/500000, Average Reward (last 1000 episodes): 0.6370
# Episode 499000/500000, Average Reward (last 1000 episodes): 0.8130
# Episode 500000/500000, Average Reward (last 1000 episodes): 0.7020
# 训练完成！访问了87个不同的状态。

# %%
# num_episodes = 500000
# log_interval = 1000

# print(f"开始训练，共{num_episodes}个episode...")
# Q, policy, episode_rewards, avg_rewards, episode_Q_changes = mc_control_epsilon_greedy(
#     env, 
#     num_episodes=num_episodes,
#     epsilon=0.1,
#     log_interval=log_interval
# )

# print(f"训练完成！访问了{len(Q)}个不同的状态。")

# %% [markdown]
# ## 可视化1: 学习曲线
#
# 显示平均奖励随训练步数的变化。

# %%
plt.figure(figsize=(12, 5))

# 创建子图1: 平均奖励
plt.subplot(1, 2, 1)
episodes, avg_rewards_data = zip(*avg_rewards)
plt.plot(episodes, avg_rewards_data, 'b-', linewidth=2)
plt.xlabel('Episode')
plt.ylabel('Average Reward (last 1000 episodes)')
plt.title('Learning Curve - Average Reward')
plt.grid(True, alpha=0.3)

# 创建子图2: 原始奖励
plt.subplot(1, 2, 2)
window_size = 100
if len(episode_rewards) > window_size:
    smoothed_rewards = np.convolve(episode_rewards, np.ones(window_size)/window_size, mode='valid')
    plt.plot(range(window_size, len(episode_rewards) + 1), smoothed_rewards, 'r-', linewidth=1, alpha=0.7, label=f'Smoothed ({window_size}ep)')
plt.plot(episode_rewards, 'g-', alpha=0.3, linewidth=0.5, label='Raw')
plt.xlabel('Episode')
plt.ylabel('Episode Reward')
plt.title('Reward Progression')
plt.grid(True, alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 可视化2: Q值变化
#
# 显示Q值在训练过程中的变化，这反映了学习进度。

# %%
plt.figure(figsize=(12, 5))

# 子图1: Q值变化
plt.subplot(1, 2, 1)
window = 100
if len(episode_Q_changes) > window:
    smoothed_Q_changes = np.convolve(episode_Q_changes, np.ones(window)/window, mode='valid')
    plt.plot(range(window, len(episode_Q_changes) + 1), smoothed_Q_changes, 'purple', linewidth=2, label=f'Smoothed ({window}ep)')
plt.plot(episode_Q_changes, 'orange', alpha=0.3, linewidth=0.5, label='Raw')
plt.xlabel('Episode')
plt.ylabel('Total Q-value Change')
plt.title('Q-value Changes During Training')
plt.grid(True, alpha=0.3)
plt.legend()

# 子图2: 累计Q值变化
plt.subplot(1, 2, 2)
cumulative_Q_changes = np.cumsum(episode_Q_changes)
plt.plot(cumulative_Q_changes, 'b-', linewidth=2)
plt.xlabel('Episode')
plt.ylabel('Cumulative Q-value Change')
plt.title('Cumulative Q-value Changes')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 可视化3: Q值分布
#
# 分析学习到的Q值的分布。

# %%
all_q_values = []
for state in Q:
    all_q_values.extend(Q[state])
all_q_values = np.array(all_q_values)

plt.figure(figsize=(10, 6))

# 直方图
plt.subplot(2, 2, 1)
plt.hist(all_q_values, bins=50, edgecolor='black', alpha=0.7)
plt.xlabel('Q-value')
plt.ylabel('Frequency')
plt.title('Distribution of Q-values')
plt.grid(True, alpha=0.3)

# 箱线图
plt.subplot(2, 2, 2)
plt.boxplot(all_q_values, vert=True, patch_artist=True)
plt.ylabel('Q-value')
plt.title('Box Plot of Q-values')
plt.grid(True, alpha=0.3)

# Q值统计
plt.subplot(2, 2, 3)
stats_text = f"""
Q-value Statistics:
Mean: {np.mean(all_q_values):.4f}
Std: {np.std(all_q_values):.4f}
Min: {np.min(all_q_values):.4f}
25%: {np.percentile(all_q_values, 25):.4f}
50%: {np.percentile(all_q_values, 50):.4f}
75%: {np.percentile(all_q_values, 75):.4f}
Max: {np.max(all_q_values):.4f}
"""
plt.text(0.1, 0.5, stats_text, fontsize=10, transform=plt.gca().transAxes, 
         verticalalignment='center', fontfamily='monospace')
plt.axis('off')

# QQ图
plt.subplot(2, 2, 4)
from scipy import stats
stats.probplot(all_q_values, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 可视化4: 策略可视化
#
# 将学习到的策略可视化，显示在不同状态下推荐的动作。

# %%
# 提取状态和最佳动作
states = list(Q.keys())
states.sort()

# 创建策略矩阵
max_sum = max(s[0] for s in states if isinstance(s[0], (int, float)))
max_cards = max(s[1] for s in states)
max_special = max(s[2] for s in states)

policy_matrix_hit = np.full((int(max_sum * 2) + 1, max_cards + 1), np.nan)  # 乘以2是因为有0.5
policy_matrix_stand = np.full((int(max_sum * 2) + 1, max_cards + 1), np.nan)

for state in states:
    sum_val, cards, special = state
    best_action = np.argmax(Q[state])
    
    idx_sum = int(sum_val * 2)  # 乘以2处理0.5
    idx_cards = cards
    
    if best_action == 1:  # Hit
        policy_matrix_hit[idx_sum, idx_cards] = Q[state][best_action]
        policy_matrix_stand[idx_sum, idx_cards] = np.nan
    else:  # Stand
        policy_matrix_stand[idx_sum, idx_cards] = Q[state][best_action]
        policy_matrix_hit[idx_sum, idx_cards] = np.nan

plt.figure(figsize=(15, 6))

# Hit动作热力图
plt.subplot(1, 2, 1)
mask_hit = np.isnan(policy_matrix_hit)
plt.imshow(policy_matrix_hit, cmap='RdYlBu', aspect='auto', interpolation='nearest')
plt.colorbar(label='Q-value')
plt.xlabel('Number of Cards')
plt.ylabel('Sum Value × 2')
plt.title('Optimal Policy - HIT Action (Q-values)')
plt.xticks(range(max_cards + 1))
 
# 添加数值标签
for i in range(policy_matrix_hit.shape[0]):
    for j in range(policy_matrix_hit.shape[1]):
        if not np.isnan(policy_matrix_hit[i, j]):
            plt.text(j, i, f'{policy_matrix_hit[i, j]:.1f}', 
                     ha='center', va='center', fontsize=8, color='black')

# Stand动作热力图
plt.subplot(1, 2, 2)
mask_stand = np.isnan(policy_matrix_stand)
plt.imshow(policy_matrix_stand, cmap='RdYlBu', aspect='auto', interpolation='nearest')
plt.colorbar(label='Q-value')
plt.xlabel('Number of Cards')
plt.ylabel('Sum Value × 2')
plt.title('Optimal Policy - STAND Action (Q-values)')
plt.xticks(range(max_cards + 1))

# 添加数值标签
for i in range(policy_matrix_stand.shape[0]):
    for j in range(policy_matrix_stand.shape[1]):
        if not np.isnan(policy_matrix_stand[i, j]):
            plt.text(j, i, f'{policy_matrix_stand[i, j]:.1f}', 
                     ha='center', va='center', fontsize=8, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 可视化5: 动作偏好分析
#
# 分析在不同状态特征下，智能体更倾向于选择哪个动作。

# %%
# 分析动作偏好
action_counts = {'HIT': 0, 'STAND': 0}
sum_by_action = {'HIT': 0, 'STAND': 0}
cards_by_action = {'HIT': 0, 'STAND': 0}
special_by_action = {'HIT': 0, 'STAND': 0}

for state in Q:
    sum_val, cards, special = state
    best_action = np.argmax(Q[state])
    
    if best_action == 1:  # Hit
        action_counts['HIT'] += 1
        sum_by_action['HIT'] += sum_val
        cards_by_action['HIT'] += cards
        special_by_action['HIT'] += special
    else:  # Stand
        action_counts['STAND'] += 1
        sum_by_action['STAND'] += sum_val
        cards_by_action['STAND'] += cards
        special_by_action['STAND'] += special

# 计算平均值
avg_sum_hit = sum_by_action['HIT'] / action_counts['HIT'] if action_counts['HIT'] > 0 else 0
avg_sum_stand = sum_by_action['STAND'] / action_counts['STAND'] if action_counts['STAND'] > 0 else 0
avg_cards_hit = cards_by_action['HIT'] / action_counts['HIT'] if action_counts['HIT'] > 0 else 0
avg_cards_stand = cards_by_action['STAND'] / action_counts['STAND'] if action_counts['STAND'] > 0 else 0
avg_special_hit = special_by_action['HIT'] / action_counts['HIT'] if action_counts['HIT'] > 0 else 0
avg_special_stand = special_by_action['STAND'] / action_counts['STAND'] if action_counts['STAND'] > 0 else 0

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# 动作分布
ax1 = axes[0, 0]
actions = list(action_counts.keys())
counts = list(action_counts.values())
bars = ax1.bar(actions, counts, color=['lightcoral', 'lightblue'])
ax1.set_xlabel('Action')
ax1.set_ylabel('Count')
ax1.set_title('Action Distribution in Learned Policy')
ax1.grid(True, alpha=0.3)
# 添加数值标签
for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + 5,
             f'{count}', ha='center', va='bottom')

# 平均状态特征
ax2 = axes[0, 1]
features = ['Sum', 'Cards', 'Special']
hit_means = [avg_sum_hit, avg_cards_hit, avg_special_hit]
stand_means = [avg_sum_stand, avg_cards_stand, avg_special_stand]

x = np.arange(len(features))
width = 0.35

bars1 = ax2.bar(x - width/2, hit_means, width, label='HIT', color='lightcoral')
bars2 = ax2.bar(x + width/2, stand_means, width, label='STAND', color='lightblue')

ax2.set_xlabel('Feature')
ax2.set_ylabel('Average Value')
ax2.set_title('Average State Features by Action')
ax2.set_xticks(x)
ax2.set_xticklabels(features)
ax2.legend()
ax2.grid(True, alpha=0.3)

# 状态特征分布
ax3 = axes[1, 0]
sum_values = [s[0] for s in states]
card_counts = [s[1] for s in states]
special_counts = [s[2] for s in states]

ax3.hist(sum_values, bins=20, alpha=0.7, edgecolor='black')
ax3.set_xlabel('Sum Value')
ax3.set_ylabel('Frequency')
ax3.set_title('Distribution of Sum Values')
ax3.grid(True, alpha=0.3)

# 卡片数量分布
ax4 = axes[1, 1]
unique_cards, card_counts_vals = np.unique(card_counts, return_counts=True)
ax4.bar(unique_cards, card_counts_vals, alpha=0.7, edgecolor='black')
ax4.set_xlabel('Number of Cards')
ax4.set_ylabel('Frequency')
ax4.set_title('Distribution of Card Counts')
ax4.set_xticks(unique_cards)
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 可视化6: 最终评估
#
# 使用学习到的策略进行1000次测试episode，评估性能。

# %%
def evaluate_policy(env, policy, num_episodes=1000):
    total_rewards = []
    episode_lengths = []
    outcomes = []  # 1=赢, 0=平, -1=输
    
    for i in range(num_episodes):
        state, _ = env.reset()
        episode_reward = 0
        steps = 0
        
        for t in range(100):  
            probs = policy(state)
            action = np.random.choice(np.arange(len(probs)), p=probs)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            
            episode_reward += reward
            steps += 1
            
            if done:
                break
            
            state = next_state
        
        total_rewards.append(episode_reward)
        episode_lengths.append(steps)
        
        if episode_reward > 0:
            outcomes.append(1)  # 赢
        elif episode_reward == 0:
            outcomes.append(0)  # 平
        else:
            outcomes.append(-1)  # 输
    
    return total_rewards, episode_lengths, outcomes

# 评估策略
print("评估学习到的策略...")
test_rewards, test_lengths, test_outcomes = evaluate_policy(env, policy, num_episodes=1000)

# 计算统计数据
win_rate = sum(1 for o in test_outcomes if o == 1) / len(test_outcomes) * 100
draw_rate = sum(1 for o in test_outcomes if o == 0) / len(test_outcomes) * 100
loss_rate = sum(1 for o in test_outcomes if o == -1) / len(test_outcomes) * 100

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# 奖励分布
ax1 = axes[0, 0]
unique_rewards, counts = np.unique(test_rewards, return_counts=True)
bars = ax1.bar(unique_rewards, counts, alpha=0.7, edgecolor='black')
ax1.set_xlabel('Reward')
ax1.set_ylabel('Frequency')
ax1.set_title('Reward Distribution in Test Episodes')
ax1.grid(True, alpha=0.3)
# 添加数值标签
for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + 5,
             f'{count}', ha='center', va='bottom', fontsize=9)

# 输赢比例
ax2 = axes[0, 1]
labels = ['Win', 'Draw', 'Loss']
sizes = [win_rate, draw_rate, loss_rate]
colors = ['lightgreen', 'lightblue', 'lightcoral']
ax2.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
ax2.axis('equal')
ax2.set_title(f'Test Results (n={len(test_outcomes)})')

# 平均奖励
ax3 = axes[0, 2]
ax3.bar(['Average'], [np.mean(test_rewards)], color='orange', alpha=0.7)
ax3.set_ylabel('Average Reward')
ax3.set_title(f'Average Test Reward: {np.mean(test_rewards):.4f}')
ax3.grid(True, alpha=0.3)
# 添加误差条
ax3.errorbar(['Average'], [np.mean(test_rewards)], yerr=[np.std(test_rewards)], 
             fmt='none', color='black', capsize=5)

# 回合长度分布
ax4 = axes[1, 0]
ax4.hist(test_lengths, bins=20, alpha=0.7, edgecolor='black')
ax4.set_xlabel('Episode Length (steps)')
ax4.set_ylabel('Frequency')
ax4.set_title('Distribution of Episode Lengths')
ax4.grid(True, alpha=0.3)

# 奖励vs长度
ax5 = axes[1, 1]
scatter = ax5.scatter(test_lengths, test_rewards, c=test_rewards, 
                      cmap='RdYlBu', alpha=0.6, edgecolors='black', linewidth=0.5)
ax5.set_xlabel('Episode Length')
ax5.set_ylabel('Reward')
ax5.set_title('Reward vs Episode Length')
plt.colorbar(scatter, ax=ax5, label='Reward')
ax5.grid(True, alpha=0.3)

# 统计摘要
ax6 = axes[1, 2]
stats_text = f"""
Test Results Summary:

Total Episodes: {len(test_rewards)}

Reward Statistics:
Mean: {np.mean(test_rewards):.4f}
Std: {np.std(test_rewards):.4f}
Min: {np.min(test_rewards):.1f}
Max: {np.max(test_rewards):.1f}

Episode Length Statistics:
Mean: {np.mean(test_lengths):.2f} steps
Std: {np.std(test_lengths):.2f}
Min: {np.min(test_lengths)} steps
Max: {np.max(test_lengths)} steps

Win/Loss Results:
Win Rate: {win_rate:.2f}%
Draw Rate: {draw_rate:.2f}%
Loss Rate: {loss_rate:.2f}%
"""
ax6.text(0.1, 0.5, stats_text, fontsize=9, transform=ax6.transAxes, 
         verticalalignment='center', fontfamily='monospace')
ax6.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 评估学习到的策略...

# %% [markdown]
# ## 结论
#
# 通过以上可视化，我们可以看到：
#
# 1. **学习进度**：平均奖励随训练逐渐提高，表明智能体在学习
# 2. **Q值收敛**：Q值变化逐渐减小，说明策略正在收敛
# 3. **策略模式**：热力图显示了在不同状态下的最优动作
# 4. **性能评估**：测试结果表明策略的有效性
